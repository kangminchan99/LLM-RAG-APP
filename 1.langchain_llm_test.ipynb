# %%
# LangChain + OpenAI 연동 라이브러리 + 환경변수 관리 라이브러리를 설치
# %pip install langchain-openai python-dotenv
# Out:
# Requirement already satisfied: langchain-openai in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (1.1.11)
# Requirement already satisfied: python-dotenv in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-openai) (2.29.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.18 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-openai) (1.2.20)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.14.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (9.1.4)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.7.20)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (6.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.12.1)
# Requirement already satisfied: sniffio in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: tqdm>4 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: requests>=2.26.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: regex>=2022.1.18 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.2.28)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.11)
# Requirement already satisfied: certifi in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.11.7)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.25.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (1.0.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/minchan/.pyenv/versions/3.10.20/envs/llm_app/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.6)
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# .env 파일에서 환경변수를 읽어와 시스템 환경변수로 등록
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# (*권장*)ChatOpenAI()는 환경변수에서 OPENAI_API_KEY를 자동으로 찾으므로 .env 파일에 OPENAI_API_KEY로 설정해두면 별도의 API 키 전달 없이도 LLM을 사용할 수 있음
llm = ChatOpenAI()


# OPENAI_API_KEY 말고 다른 이름으로 설정한 경우
# import os
# from langchain_openai import ChatOpenAI
# api_key = os.getenv("YOUR_API_KEY_HERE")

# llm = ChatOpenAI(api_key=api_key)

# %%
# invoke()로 LLM에 메시지를 전달하고 응답을 받음
ai_message = llm.invoke("강민찬입니다. 반갑습니다.")

# %%
ai_message.content
# Out:
# '안녕하세요, 반갑습니다! 무엇을 도와드릴까요?'
